# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from sklearn.tree import export_graphviz
import numpy as np
import graphviz


#Scale 변환: 평균, 표준편차, 기준

from sklearn.preprocessing import StandardScaler

#주성분 분석
from sklearn.decomposition import PCA

#회귀분석
from statsmodels.formula.api import ols
#qqplot, 회귀분석의 상수항 추가
from statsmodels.api import qqplot, add_constant
#선형 모델 formula(y~X1+X2+...)

import statsmodels.formula.api as smf
#평가함수
from statsmodels.tools.eval_measures import rmse
from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier as GBC
import seaborn as sns
# 주피터 사용시 그래프자동출력 옵션
matplotlib.rc('font', family ='Malgun Gothic')

import statsmodels.formula.api as smf # 선형모델 formula(y ~ x1 +x2+ x3)
import statsmodels.api as sm
# ols Ordinary Least Squares (최소자승법 라이브러리)
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm


from statsmodels.api import Logit

from sklearn.metrics import accuracy_score

from sklearn.metrics import confusion_matrix
# 한글 맑은 고딕 적용
matplotlib.rc('font',family='NanumGothic')

# matplotlib  패키지 한글 깨짐 처리
# 한글 폰트(맑은 고딕) 적용 : 윈도우, 구글 콜랩
matplotlib.rc('font',family='NanumGothic')
plt.rc('font',family='NanumGothic')

# seaborn에서 한글 깨짐 해결:unicode minus 사용 않기 위한 설정(minus 깨짐 현상 방지)
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# ## 데이터 불러오기

# %%
df = pd.read_csv('./DATA/insu_request.csv', engine = 'python', encoding ='EUC-KR')
df
# Out:
#       customer_id review_cat judge  gender  age    insu_id insu_contract_date  \
# 0         C112379       혈액검사    재검       1   69  INS-10484          08-Dec-14
# 1         C112379       혈액검사    재검       1   69  INS-10484          08-Dec-14
# 2         C112379       혈액검사    재검       1   69  INS-10484          08-Dec-14
# 3         C112379       혈액검사    재검       1   69  INS-10484          08-Dec-14
# 4         C112379       혈액검사    재검       1   69  INS-10484          08-Dec-14
# ...           ...        ...   ...     ...  ...        ...                ...
# 49444     C134250       일반검진    승인       2   52  INS-18892          15-Sep-15
# 49445     C134250       일반검진    승인       2   52  INS-18892          15-Sep-15
# 49446     C134250       일반검진    승인       2   52  INS-18892          15-Sep-15
# 49447     C134250       일반검진    승인       2   52  INS-18892          15-Sep-15
# 49448     C134251       일반검진    재검       2   57  INS-15476          20-Jun-15
#
#       insu_prod_id insu_prod_name                         req_id  ...  \
# 0         PR-20363     가족 만족 보험 1  C112379-20101118-12660-01-001  ...
# 1         PR-20363     가족 만족 보험 1  C112379-20110314-17403-01-001  ...
# 2         PR-20363     가족 만족 보험 1  C112379-20110314-17403-01-001  ...
# 3         PR-20363     가족 만족 보험 1  C112379-20110314-17403-01-001  ...
# 4         PR-20363     가족 만족 보험 1  C112379-20110314-17403-01-001  ...
# ...            ...            ...                            ...  ...
# 49444     PR-20765         건강 보살핌  C134250-20130607-14972-01-001  ...
# 49445     PR-20765         건강 보살핌  C134250-20130607-14972-01-001  ...
# 49446     PR-20765         건강 보살핌  C134250-20130607-14972-01-001  ...
# 49447     PR-20765         건강 보살핌  C134250-20130607-14972-01-001  ...
# 49448     PR-20083         울라트 보험  C134251-20110630-13303-01-001  ...
#
#        sick_3rd dg_cat dg_start_date dg_end_date dg_duration insu_req_amount  \
# 0           NaN     외래     24-Oct-15   16-Nov-15          24          424498
# 1           NaN     외래     17-Feb-16   17-Feb-16           1           34950
# 2           NaN     외래     24-Feb-16   24-Feb-16           1               0
# 3           NaN     외래     02-Mar-16   02-Mar-16           1               0
# 4           NaN     외래     09-Mar-16   09-Mar-16           1           16000
# ...         ...    ...           ...         ...         ...             ...
# 49444       NaN     외래     25-Sep-17   25-Sep-17           1           19100
# 49445       NaN     외래     25-Sep-17   25-Sep-17           1           42970
# 49446       NaN     외래     20-Nov-17   20-Nov-17           1           31200
# 49447       NaN     외래     13-Dec-17   13-Dec-17           1           33200
# 49448       NaN     외래     16-Jun-16   16-Jun-16           1          111570
#
#       insu_pay_amount insu_pay_date  insu_duration  insu_cum_amount
# 0            724498.0     18-Nov-15             11          1320000
# 1            490079.0     13-Mar-16             15          1800000
# 2            490079.0     13-Mar-16             15          1800000
# 3            490079.0     13-Mar-16             15          1800000
# 4            490079.0     13-Mar-16             15          1800000
# ...               ...           ...            ...              ...
# 49444        140900.0     06-Jun-18             33          1650000
# 49445        140900.0     06-Jun-18             33          1650000
# 49446        140900.0     06-Jun-18             33          1650000
# 49447        140900.0     06-Jun-18             33          1650000
# 49448        111570.0     28-Jun-16             12          2640000
#
# [49449 rows x 24 columns]

# %%
df_na =df[df['insu_pay_amount'].isna()]
df_na
# Out:
#       customer_id review_cat judge  gender  age    insu_id insu_contract_date  \
# 458       C113058       혈액검사    재검       1   61  INS-14063          25-Jan-15
# 921       C113295       혈액검사    승인       1   59  INS-13471          27-Nov-14
# 1325      C113511       혈액검사    재검       1   59  INS-13343          12-Nov-14
# 1629      C113724       혈액검사    승인       1   60  INS-20374          26-Mar-15
# 1963      C113953       혈액검사    승인       1   59  INS-14285          18-Feb-15
# 1965      C113954       혈액검사    승인       1   59  INS-21145          27-Sep-15
# 2612      C114408       일반검진    재검       1   58  INS-20736          16-Jun-15
# 2664      C114449       혈액검사    재검       1   57  INS-13802          29-Dec-14
# 3602      C115129       혈액검사    승인       1   56  INS-14884          20-Apr-15
# 3870      C115391       혈액검사    재검       1   55  INS-21028          29-Aug-15
# 5021      C116121       일반검진    재검       1   54  INS-20859          20-Jul-15
# 5035      C116146       혈액검사    승인       1   54  INS-12260          17-Aug-15
# 5077      C116190       혈액검사    재검       1   54  INS-14912          20-Apr-15
# 6954      C117231       혈액검사    재검       1   51  INS-15266          15-Jun-15
# 9193      C118360       혈액검사    재검       1   48  INS-12462          24-Aug-15
# 10628     C119320       혈액검사    재검       1   43  INS-13538          02-Dec-14
# 10884     C119445       혈액검사    재검       1   43  INS-18226          20-Jul-15
# 12500     C120561       혈액검사    재검       1   36  INS-15003          29-Apr-15
# 13044     C120894       일반검진    승인       1   33  INS-19482          29-Nov-14
# 13315     C121089       혈액검사    재검       1   32  INS-14568          17-Mar-15
# 13450     C121171       혈액검사    승인       1   31  INS-13867          11-Jan-15
# 14723     C122495       혈액검사    승인       1   19  INS-20985          17-Aug-15
# 14740     C122512       혈액검사    재검       1   60  INS-21084          12-Sep-15
# 15014     C123169       혈액검사    승인       2   62  INS-16002          25-Aug-15
# 15046     C123247       혈액검사    재검       2   60  INS-19062          06-Oct-14
# 15778     C123496       혈액검사    재검       2   59  INS-19646          18-Dec-14
# 16525     C123703       혈액검사    승인       2   60  INS-20531          29-Apr-15
# 16562     C123754       일반검진    승인       2   60  INS-15621          08-Jul-15
# 19202     C124540       일반검진    재검       2   57  INS-16395          15-Sep-15
# 19578     C124566       혈액검사    재검       2   57  INS-10313          12-Sep-15
# 23979     C125686       혈액검사    재검       2   53  INS-19513          06-Dec-14
# 24984     C125854       혈액검사    재검       2   53  INS-16403          26-Sep-15
# 26058     C126103       혈액검사    승인       2   53  INS-15736          15-Jul-15
# 27133     C126280       혈액검사    재검       2   52  INS-15694          22-Jul-15
# 28543     C126591       혈액검사    승인       2   52  INS-12294          29-Aug-15
# 29619     C126783       혈액검사    승인       2   51  INS-14780          11-Feb-15
# 34768     C127944       혈액검사    재검       2   46  INS-19519          29-Nov-14
# 35407     C128053       일반검진    승인       2   46  INS-10603          22-Aug-15
# 35633     C128098       혈액검사    재검       2   46  INS-14581          21-Mar-15
# 37095     C128473       혈액검사    재검       2   44  INS-18125          05-Sep-15
# 39126     C129116       혈액검사    재검       2   39  INS-19681          21-Dec-14
# 39760     C129362       혈액검사    승인       2   39  INS-14106          27-Jan-15
# 40684     C129429       혈액검사    재검       2   37  INS-14205          10-Dec-14
# 41332     C129720       일반검진    재검       2   37  INS-15359          22-Jun-15
# 41695     C129833       혈액검사    재검       2   35  INS-13427          22-Nov-14
# 42060     C130031       일반검진    재검       2   34  INS-14279          09-Feb-15
# 42481     C130300       혈액검사    승인       2   31  INS-12400          02-Feb-15
# 42521     C130325       혈액검사    승인       2   30  INS-18863          25-Oct-14
# 45879     C131999       혈액검사    승인       2   58  INS-14470          21-Feb-15
# 46754     C132469       혈액검사    승인       2   29  INS-13748          25-Dec-14
# 48275     C133322       혈액검사    재검       2   27  INS-20325          29-Jan-15
# 48356     C133340       혈액검사    재검       2   56  INS-14344          07-Feb-15
#
#       insu_prod_id insu_prod_name                         req_id  ...  \
# 458       PR-20069           건강보험  C113058-20100913-10514-01-001  ...
# 921       PR-20069           건강보험  C113295-20101109-17513-01-001  ...
# 1325      PR-20069           건강보험  C113511-20120629-11925-01-001  ...
# 1629      PR-20569      조심조심 보험 4  C113724-20120224-14058-01-001  ...
# 1963      PR-20606       단체보험(상해)  C113953-20100712-17303-01-001  ...
# 1965      PR-20569      조심조심 보험 4  C113954-20110328-15469-01-001  ...
# 2612      PR-20569      조심조심 보험 4  C114408-20110603-13906-01-001  ...
# 2664      PR-20069           건강보험  C114449-20101105-11376-01-001  ...
# 3602      PR-20083         울라트 보험  C115129-20100719-16557-01-001  ...
# 3870      PR-20569      조심조심 보험 4  C115391-20110623-11333-02-001  ...
# 5021      PR-20569      조심조심 보험 4  C116121-20121121-16177-01-001  ...
# 5035      PR-20205  All My Life 1  C116146-20120208-14461-02-001  ...
# 5077      PR-20083         울라트 보험  C116190-20101019-10392-01-001  ...
# 6954      PR-20083         울라트 보험  C117231-20130827-16457-01-001  ...
# 9193      PR-20205  All My Life 1  C118360-20110617-16221-01-001  ...
# 10628     PR-20069           건강보험  C119320-20100303-13348-01-001  ...
# 10884     PR-20199     평생 건강 보장 1  C119445-20130522-11815-01-001  ...
# 12500     PR-20581        통합보험 +3  C120561-20100615-13632-01-001  ...
# 13044     PR-20569      조심조심 보험 4  C120894-20111019-16723-01-001  ...
# 13315     PR-20069           건강보험  C121089-20130730-13027-01-001  ...
# 13450     PR-20915        통합보험 +2  C121171-20110613-19165-01-001  ...
# 14723     PR-20569      조심조심 보험 4  C122495-20110808-15604-01-001  ...
# 14740     PR-20569      조심조심 보험 4  C122512-20120409-16011-01-001  ...
# 15014     PR-20083         울라트 보험  C123169-20120221-17465-01-001  ...
# 15046     PR-20569      조심조심 보험 4  C123247-20110215-17689-01-001  ...
# 15778     PR-20569      조심조심 보험 4  C123496-20100305-18951-01-001  ...
# 16525     PR-20569      조심조심 보험 4  C123703-20110627-16903-01-001  ...
# 16562     PR-20083         울라트 보험  C123754-20120406-18141-01-001  ...
# 19202     PR-20083         울라트 보험  C124540-20120511-18504-01-001  ...
# 19578     PR-20363     가족 만족 보험 1  C124566-20130429-12833-01-001  ...
# 23979     PR-20569      조심조심 보험 4  C125686-20100610-13281-01-001  ...
# 24984     PR-20083         울라트 보험  C125854-20110905-17677-01-001  ...
# 26058     PR-20083         울라트 보험  C126103-20110816-12975-01-001  ...
# 27133     PR-20083         울라트 보험  C126280-20101206-10097-01-001  ...
# 28543     PR-20205  All My Life 1  C126591-20120116-20512-01-001  ...
# 29619     PR-20083         울라트 보험  C126783-20100728-10209-01-001  ...
# 34768     PR-20569      조심조심 보험 4  C127944-20100517-17695-01-001  ...
# 35407     PR-20409        평생 보험 2  C128053-20130505-10154-01-001  ...
# 35633     PR-20069           건강보험  C128098-20101202-11788-01-001  ...
# 37095     PR-20199     평생 건강 보장 1  C128473-20110930-15673-01-001  ...
# 39126     PR-20569      조심조심 보험 4  C129116-20100519-10871-01-001  ...
# 39760     PR-20069           건강보험  C129362-20110721-14471-01-001  ...
# 40684     PR-20069           건강보험  C129429-20120104-10507-01-001  ...
# 41332     PR-20083         울라트 보험  C129720-20110404-11978-01-001  ...
# 41695     PR-20069           건강보험  C129833-20110413-11621-01-001  ...
# 42060     PR-20069           건강보험  C130031-20111212-19377-01-001  ...
# 42481     PR-20205  All My Life 1  C130300-20100430-16305-01-001  ...
# 42521     PR-20765         건강 보살핌  C130325-20091215-11018-01-001  ...
# 45879     PR-20069           건강보험  C131999-20110927-18778-01-001  ...
# 46754     PR-20069           건강보험  C132469-20100401-17870-01-001  ...
# 48275     PR-20569      조심조심 보험 4  C133322-20100914-10171-01-001  ...
# 48356     PR-20069           건강보험  C133340-20120712-12996-01-001  ...
#
#        sick_3rd dg_cat dg_start_date dg_end_date dg_duration insu_req_amount  \
# 458         NaN     외래     19-Oct-15   19-Oct-15           1               0
# 921         NaN     외래     23-Nov-15   23-Nov-15           1               0
# 1325        NaN     외래     30-Aug-17   30-Aug-17           1               0
# 1629        NaN     외래     18-Mar-17   18-Mar-17           1               0
# 1963        NaN     외래     01-Aug-15   01-Aug-15           1               0
# 1965        NaN     외래     24-Apr-16   24-Apr-16           1               0
# 2612        NaN     외래     12-Jul-16   12-Jul-16           1               0
# 2664        NaN     외래     30-Nov-15   30-Nov-15           1               0
# 3602        NaN     외래     03-Aug-15   03-Aug-15           1               0
# 3870        NaN     외래     17-Aug-16   17-Aug-16           1               0
# 5021        NaN     외래     30-Dec-17   30-Dec-17           1               0
# 5035        NaN     외래     15-Feb-17   15-Feb-17           1               0
# 5077        NaN     외래     04-Jan-16   04-Jan-16           1               0
# 6954        NaN     외래     29-Sep-18   29-Sep-18           1               0
# 9193        NaN     외래     27-Jun-16   27-Jun-16           1               0
# 10628       NaN     외래     10-May-15   10-May-15           1               0
# 10884       NaN     외래     30-May-18   30-May-18           1               0
# 12500       NaN     외래     18-Jul-15   18-Jul-15           1               0
# 13044       NaN     외래     01-Nov-16   01-Nov-16           1               0
# 13315       NaN     외래     29-Aug-18   29-Aug-18           1               0
# 13450       NaN     외래     29-Jun-16   29-Jun-16           1               0
# 14723       NaN     외래     28-Sep-16   28-Sep-16           1               0
# 14740       NaN     외래     10-May-17   10-May-17           1               0
# 15014       NaN     외래     12-Mar-17   12-Mar-17           1               0
# 15046       NaN     외래     29-Mar-16   29-Mar-16           1               0
# 15778       NaN     외래     15-Apr-15   15-Apr-15           1               0
# 16525       NaN     외래     17-Sep-16   17-Sep-16           1               0
# 16562       NaN     외래     03-May-17   03-May-17           1               0
# 19202       NaN     외래     25-Jun-17   25-Jun-17           1               0
# 19578       NaN     외래     15-May-18   15-May-18           1               0
# 23979       NaN     외래     25-Jul-15   25-Jul-15           1               0
# 24984       NaN     외래     14-Sep-16   14-Sep-16           1               0
# 26058       NaN     외래     29-Aug-16   29-Aug-16           1               0
# 27133       M48     외래     27-Dec-15   27-Dec-15           1               0
# 28543       NaN     외래     29-Jan-17   29-Jan-17           1               0
# 29619       NaN     외래     09-Nov-15   09-Nov-15           1               0
# 34768       M51     외래     09-Jun-15   09-Jun-15           1               0
# 35407       NaN     외래     17-Jun-18   17-Jun-18           1               0
# 35633       NaN     외래     21-Dec-15   21-Dec-15           1               0
# 37095       NaN     외래     15-Oct-16   15-Oct-16           1               0
# 39126       NaN     외래     13-Jun-15   13-Jun-15           1               0
# 39760       NaN     외래     28-Aug-16   28-Aug-16           1               0
# 40684       NaN     외래     25-Jan-17   25-Jan-17           1               0
# 41332       NaN     외래     18-May-16   18-May-16           1               0
# 41695       NaN     외래     01-May-16   01-May-16           1               0
# 42060       NaN     외래     01-Feb-17   01-Feb-17           1               0
# 42481       NaN     외래     30-May-15   30-May-15           1               0
# 42521       NaN     외래     28-Dec-14   28-Dec-14           1               0
# 45879       NaN     외래     18-Oct-16   18-Oct-16           1               0
# 46754       NaN     외래     16-May-15   16-May-15           1               0
# 48275       N30     외래     10-Oct-15   10-Oct-15           1               0
# 48356       NaN     외래     25-Jul-17   25-Jul-17           1               0
#
#       insu_pay_amount insu_pay_date  insu_duration  insu_cum_amount
# 458               NaN     19-Oct-15              9           900000
# 921               NaN     23-Nov-15             12          1200000
# 1325              NaN     30-Aug-17             33          3300000
# 1629              NaN     18-Mar-17             24           960000
# 1963              NaN     01-Aug-15              6          2400000
# 1965              NaN     24-Apr-16              7           280000
# 2612              NaN     12-Jul-16             13           520000
# 2664              NaN     30-Nov-15             11          1100000
# 3602              NaN     03-Aug-15              4           880000
# 3870              NaN     17-Aug-16             12           480000
# 5021              NaN     30-Dec-17             29          1160000
# 5035              NaN     15-Feb-17             18          3600000
# 5077              NaN     04-Jan-16              9          1980000
# 6954              NaN     29-Sep-18             39          8580000
# 9193              NaN     27-Jun-16             10          2000000
# 10628             NaN     10-May-15              5           500000
# 10884             NaN     30-May-18             34         10200000
# 12500             NaN     18-Jul-15              3           450000
# 13044             NaN     01-Nov-16             24           960000
# 13315             NaN     29-Aug-18             41          4100000
# 13450             NaN     29-Jun-16             17          2380000
# 14723             NaN     28-Sep-16             13           520000
# 14740             NaN     10-May-17             20           800000
# 15014             NaN     12-Mar-17             19          4180000
# 15046             NaN     29-Mar-16             17           680000
# 15778             NaN     15-Apr-15              4           160000
# 16525             NaN     17-Sep-16             17           680000
# 16562             NaN     03-May-17             22          4840000
# 19202             NaN     25-Jun-17             21          4620000
# 19578             NaN     15-May-18             32          3840000
# 23979             NaN     25-Jul-15              7           280000
# 24984             NaN     14-Sep-16             12          2640000
# 26058             NaN     29-Aug-16             13          2860000
# 27133             NaN     27-Dec-15              5          1100000
# 28543             NaN     29-Jan-17             17          3400000
# 29619             NaN     09-Nov-15              9          1980000
# 34768             NaN     09-Jun-15              7           280000
# 35407             NaN     17-Jun-18             34          6120000
# 35633             NaN     21-Dec-15              9           900000
# 37095             NaN     15-Oct-16             13          3900000
# 39126             NaN     13-Jun-15              6           240000
# 39760             NaN     28-Aug-16             19          1900000
# 40684             NaN     25-Jan-17             25          2500000
# 41332             NaN     18-May-16             11          2420000
# 41695             NaN     01-May-16             18          1800000
# 42060             NaN     01-Feb-17             24          2400000
# 42481             NaN     30-May-15              3           600000
# 42521             NaN     28-Dec-14              2           100000
# 45879             NaN     18-Oct-16             20          2000000
# 46754             NaN     16-May-15              5           500000
# 48275             NaN     10-Oct-15              9           360000
# 48356             NaN     25-Jul-17             29          2900000
#
# [52 rows x 24 columns]

# %%
df.isna().sum()
# Out:
# customer_id               0
# review_cat                0
# judge                     0
# gender                    0
# age                       0
# insu_id                   0
# insu_contract_date        0
# insu_prod_id              0
# insu_prod_name            0
# req_id                    0
# req_id_seq                0
# sick_main                 0
# sick_1st                  0
# sick_2nd              37949
# sick_3rd              44605
# dg_cat                    0
# dg_start_date             0
# dg_end_date               0
# dg_duration               0
# insu_req_amount           0
# insu_pay_amount          52
# insu_pay_date             0
# insu_duration             0
# insu_cum_amount           0
# dtype: int64

# %%
df = df.dropna(subset =['insu_pay_amount'])
df.isna().sum()
# Out:
# customer_id               0
# review_cat                0
# judge                     0
# gender                    0
# age                       0
# insu_id                   0
# insu_contract_date        0
# insu_prod_id              0
# insu_prod_name            0
# req_id                    0
# req_id_seq                0
# sick_main                 0
# sick_1st                  0
# sick_2nd              37906
# sick_3rd              44556
# dg_cat                    0
# dg_start_date             0
# dg_end_date               0
# dg_duration               0
# insu_req_amount           0
# insu_pay_amount           0
# insu_pay_date             0
# insu_duration             0
# insu_cum_amount           0
# dtype: int64

# %% [markdown]
# ## 청구금액, 지급금액 customer id 로 그룹화

# %%
# df['p_sick'] =df['sick_main'].apply(lambda x : x[0])
df_id= df.groupby(['customer_id','req_id'])
df_req = df.groupby(['customer_id','req_id'])[['insu_req_amount']].sum()
df_pay = df.groupby(['customer_id','req_id'])[['insu_pay_amount']].mean()
df_cum = df.groupby(['customer_id','req_id'])[['insu_cum_amount']].max()
df_dur = df.groupby(['customer_id','req_id'])[['insu_duration']].max()
# df_kin = df.groupby(['customer_id','req_id','p_sick'])[['insu_prod_name']].max()

# %%
df_all =pd.merge(df_req, df_pay, on = ['customer_id','req_id'])
df_all =pd.merge(df_all, df_cum, on = ['customer_id','req_id'])
df_all =pd.merge(df_all, df_dur, on = ['customer_id','req_id'])
# df_all =pd.merge(df_all, df_kin, on = ['customer_id','req_id','p_sick','insu_prod_name'])

# %%
df_all.head(10)
# Out:
#                                            insu_req_amount  insu_pay_amount  \
# customer_id req_id
# C112379     C112379-20101118-12660-01-001           424498         724498.0
#             C112379-20110314-17403-01-001           198600         490079.0
# C112404     C112404-20100831-12754-01-001           808750        1008750.0
# C112411     C112411-20101111-18755-01-001           333680         553680.0
# C112570     C112570-20100730-10580-01-001           412210         412210.0
#             C112570-20130716-13737-01-001          2350069        2440069.0
# C112727     C112727-20120813-20372-01-001           201880         201880.0
# C112730     C112730-20110804-15908-01-001            50160          50160.0
#             C112730-20110831-13010-01-001           254490         254490.0
#             C112730-20120628-16359-01-001          1236256        1236256.0
#
#                                            insu_cum_amount  insu_duration
# customer_id req_id
# C112379     C112379-20101118-12660-01-001          1320000             11
#             C112379-20110314-17403-01-001          1800000             15
# C112404     C112404-20100831-12754-01-001           600000              5
# C112411     C112411-20101111-18755-01-001           240000              2
# C112570     C112570-20100730-10580-01-001           375000              3
#             C112570-20130716-13737-01-001          4875000             39
# C112727     C112727-20120813-20372-01-001          3250000             26
# C112730     C112730-20110804-15908-01-001          1440000             12
#             C112730-20110831-13010-01-001          1440000             12
#             C112730-20120628-16359-01-001          2640000             22

# %%
df_all.reset_index(level = ['customer_id','req_id'], inplace =True)

# %%
df_all.head(15)
# Out:
#    customer_id                         req_id  insu_req_amount  \
# 0      C112379  C112379-20101118-12660-01-001           424498
# 1      C112379  C112379-20110314-17403-01-001           198600
# 2      C112404  C112404-20100831-12754-01-001           808750
# 3      C112411  C112411-20101111-18755-01-001           333680
# 4      C112570  C112570-20100730-10580-01-001           412210
# 5      C112570  C112570-20130716-13737-01-001          2350069
# 6      C112727  C112727-20120813-20372-01-001           201880
# 7      C112730  C112730-20110804-15908-01-001            50160
# 8      C112730  C112730-20110831-13010-01-001           254490
# 9      C112730  C112730-20120628-16359-01-001          1236256
# 10     C112742  C112742-20101227-17471-01-001           266310
# 11     C112759  C112759-20111031-18126-01-001           371240
# 12     C112759  C112759-20120823-14754-01-001           733520
# 13     C112759  C112759-20130724-17901-01-001           692260
# 14     C112856  C112856-20120717-16134-02-001           234820
#
#     insu_pay_amount  insu_cum_amount  insu_duration
# 0          724498.0          1320000             11
# 1          490079.0          1800000             15
# 2         1008750.0           600000              5
# 3          553680.0           240000              2
# 4          412210.0           375000              3
# 5         2440069.0          4875000             39
# 6          201880.0          3250000             26
# 7           50160.0          1440000             12
# 8          254490.0          1440000             12
# 9         1236256.0          2640000             22
# 10         266310.0           375000              3
# 11         371240.0          1560000             13
# 12         733520.0          2760000             23
# 13         692260.0          4080000             34
# 14         314820.0          2875000             23

# %%
df1 = df_all.groupby(['customer_id'])['req_id'].max()
df2 = df_all.groupby(['customer_id'])['insu_req_amount'].sum()
df3 = df_all.groupby(['customer_id'])['insu_pay_amount'].sum()
df4 = df_all.groupby(['customer_id'])['insu_cum_amount'].max()
df5 = df_all.groupby(['customer_id'])['insu_duration'].max()

# %%
df_all1 =pd.merge(df1,df2, on = ['customer_id'])
df_all1 =pd.merge(df_all1, df3, on = ['customer_id'])
df_all1 =pd.merge(df_all1, df4, on = ['customer_id'])
df_all1 =pd.merge(df_all1, df5, on = ['customer_id'])
# df_all1 =pd.merge(df_all1, df6, on = ['customer_id'])
# df_all1 =pd.merge(df_all1, df7, on = 'customer_id')

# %%
df_all1.head()
# Out:
#                                     req_id  insu_req_amount  insu_pay_amount  \
# customer_id
# C112379      C112379-20110314-17403-01-001           623098        1214577.0
# C112404      C112404-20100831-12754-01-001           808750        1008750.0
# C112411      C112411-20101111-18755-01-001           333680         553680.0
# C112570      C112570-20130716-13737-01-001          2762279        2852279.0
# C112727      C112727-20120813-20372-01-001           201880         201880.0
#
#              insu_cum_amount  insu_duration
# customer_id
# C112379              1800000             15
# C112404               600000              5
# C112411               240000              2
# C112570              4875000             39
# C112727              3250000             26

# %%
df_all1['customer_cost'] = (df_all1['insu_req_amount'] - df_all1['insu_pay_amount'])/ (df_all1['insu_req_amount'])

# %% [markdown]
# ## 고객 청구 금액이 0인 경우

# %%
df_zero= df_all1[df_all1['insu_req_amount']== 0]
df_zero
# Out:
#                                     req_id  insu_req_amount  insu_pay_amount  \
# customer_id
# C112899      C112899-20130405-10628-01-001                0        5000000.0
# C112915      C112915-20130822-16206-01-001                0         100000.0
# C112928      C112928-20100303-19898-01-001                0         200000.0
# C112966      C112966-20120710-19862-01-001                0         200000.0
# C112986      C112986-20100802-19401-01-001                0         200000.0
# ...                                    ...              ...              ...
# C132759      C132759-20110916-20196-01-001                0        1200000.0
# C132821      C132821-20110412-19792-01-001                0         200000.0
# C132957      C132957-20130405-16406-01-001                0         100000.0
# C133351      C133351-20110429-17687-01-001                0         280000.0
# C134001      C134001-20100917-19273-01-001                0         200000.0
#
#              insu_cum_amount  insu_duration  customer_cost
# customer_id
# C112899              6820000             31           -inf
# C112915              7700000             35           -inf
# C112928               400000              4           -inf
# C112966              1280000             32           -inf
# C112986               360000              9           -inf
# ...                      ...            ...            ...
# C132759              2200000             22           -inf
# C132821              2860000             13           -inf
# C132957              7040000             32           -inf
# C133351              2860000             13           -inf
# C134001               800000              8           -inf
#
# [477 rows x 6 columns]

# %%
df_zero['insu_pay_amount'].describe()
# Out:
# count    4.770000e+02
# mean     1.133858e+06
# std      6.486067e+06
# min      3.000000e+04
# 25%      2.000000e+05
# 50%      2.000000e+05
# 75%      4.000000e+05
# max      1.000000e+08
# Name: insu_pay_amount, dtype: float64

# %%
df_zero['insu_pay_amount'].hist()
# Out:
# <AxesSubplot:>

# %%
df_zero['insu_pay_amount'].hist()
# Out:
# <AxesSubplot:>

# %%
df_zero['insu_pay_amount'].hist(figsize=(30,15),range = (3.000000e+04,4.000000e+05), bins = 40)
# Out:
# <AxesSubplot:>

# %%
2.000000e+05
# Out:
# 200000.0

# %%
df_zero_low = df_zero[df_zero['insu_pay_amount'] > 200000]
df_zero_low['risk'] = 1
df_zero_low
# Out:
# <ipython-input-121-b5b9a0503980>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_zero_low['risk'] = 1
#                                     req_id  insu_req_amount  insu_pay_amount  \
# customer_id
# C112899      C112899-20130405-10628-01-001                0        5000000.0
# C113107      C113107-20100325-18666-01-001                0         280000.0
# C113219      C113219-20110427-19228-01-001                0         400000.0
# C113308      C113308-20110807-10014-01-001                0         550000.0
# C113414      C113414-20111021-19179-01-001                0         620000.0
# ...                                    ...              ...              ...
# C132114      C132114-20110907-20401-01-001                0        1150000.0
# C132370      C132370-20111213-13300-01-001                0         220000.0
# C132412      C132412-20130131-17940-01-001                0         760000.0
# C132759      C132759-20110916-20196-01-001                0        1200000.0
# C133351      C133351-20110429-17687-01-001                0         280000.0
#
#              insu_cum_amount  insu_duration  customer_cost  risk
# customer_id
# C112899              6820000             31           -inf     1
# C113107                    0              0           -inf     1
# C113219               950000             19           -inf     1
# C113308              5060000             23           -inf     1
# C113414               800000             20           -inf     1
# ...                      ...            ...            ...   ...
# C132114              2300000             23           -inf     1
# C132370              3960000             18           -inf     1
# C132412              3900000             39           -inf     1
# C132759              2200000             22           -inf     1
# C133351              2860000             13           -inf     1
#
# [191 rows x 7 columns]

# %%
df_zero_high = df_zero[df_zero['insu_pay_amount'] < 200000]
df_zero_high['risk'] = 0
df_zero_high
# Out:
# <ipython-input-122-d87048aeb830>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_zero_high['risk'] = 0
#                                     req_id  insu_req_amount  insu_pay_amount  \
# customer_id
# C112915      C112915-20130822-16206-01-001                0         100000.0
# C113429      C113429-20100608-20385-02-001                0         160000.0
# C113461      C113461-20110812-18984-01-001                0         156243.0
# C113763      C113763-20120719-14690-02-001                0         100000.0
# C113886      C113886-20110310-10542-01-001                0         100000.0
# ...                                    ...              ...              ...
# C132153      C132153-20130916-21960-01-001                0         100000.0
# C132156      C132156-20111012-13729-01-001                0         100000.0
# C132515      C132515-20130520-14084-02-001                0         100000.0
# C132546      C132546-20130401-15629-01-001                0         100000.0
# C132957      C132957-20130405-16406-01-001                0         100000.0
#
#              insu_cum_amount  insu_duration  customer_cost  risk
# customer_id
# C112915              7700000             35           -inf     0
# C113429               200000              5           -inf     0
# C113461               800000             20           -inf     0
# C113763              1840000             23           -inf     0
# C113886              1500000             15           -inf     0
# ...                      ...            ...            ...   ...
# C132153              4300000             43           -inf     0
# C132156              3520000             16           -inf     0
# C132515              7040000             32           -inf     0
# C132546              6820000             31           -inf     0
# C132957              7040000             32           -inf     0
#
# [93 rows x 7 columns]

# %%
df_zero_risk =pd.merge(df_zero_high,df_zero_low, on =['customer_id', 'req_id', 'insu_req_amount', 'insu_pay_amount',
       'insu_cum_amount', 'insu_duration', 'customer_cost', 'risk'], how = 'outer')
df_zero_risk
# Out:
#                                     req_id  insu_req_amount  insu_pay_amount  \
# customer_id
# C112915      C112915-20130822-16206-01-001                0         100000.0
# C113429      C113429-20100608-20385-02-001                0         160000.0
# C113461      C113461-20110812-18984-01-001                0         156243.0
# C113763      C113763-20120719-14690-02-001                0         100000.0
# C113886      C113886-20110310-10542-01-001                0         100000.0
# ...                                    ...              ...              ...
# C132114      C132114-20110907-20401-01-001                0        1150000.0
# C132370      C132370-20111213-13300-01-001                0         220000.0
# C132412      C132412-20130131-17940-01-001                0         760000.0
# C132759      C132759-20110916-20196-01-001                0        1200000.0
# C133351      C133351-20110429-17687-01-001                0         280000.0
#
#              insu_cum_amount  insu_duration  customer_cost  risk
# customer_id
# C112915              7700000             35           -inf     0
# C113429               200000              5           -inf     0
# C113461               800000             20           -inf     0
# C113763              1840000             23           -inf     0
# C113886              1500000             15           -inf     0
# ...                      ...            ...            ...   ...
# C132114              2300000             23           -inf     1
# C132370              3960000             18           -inf     1
# C132412              3900000             39           -inf     1
# C132759              2200000             22           -inf     1
# C133351              2860000             13           -inf     1
#
# [284 rows x 7 columns]

# %%
df_zero_risk.groupby('risk').count()
# Out:
#       req_id  insu_req_amount  insu_pay_amount  insu_cum_amount  \
# risk
# 0         93               93               93               93
# 1        191              191              191              191
#
#       insu_duration  customer_cost
# risk
# 0                93             93
# 1               191            191

# %% [markdown]
# ## 고객 청구 금액이 0이 아닌경우

# %%
df_not_zero = df_all1[df_all1['insu_req_amount']!= 0]
df_not_zero
df_not_zero.reset_index(level = ['customer_id'], inplace =True)

# %%
df_not_zero['customer_cost'].hist(range= (0,0.005),figsize = (15,8), bins =30)
# Out:
# <AxesSubplot:>

# %%
df_not_zero['customer_cost'][df_not_zero["customer_cost"]>0.01].count()
# Out:
# 468

# %%
df_not_zero['customer_cost'][df_not_zero["customer_cost"]<0].count()
# Out:
# 1639

# %% [markdown]
# 0 이하는 위험군, 0.02 이상은 수익군으로 분류

# %%
df_risk_high = df_not_zero[df_not_zero['customer_cost']<0]
df_risk_high['risk'] = 1
# risk 1로 위험군
# Out:
# <ipython-input-129-f5e8e666b0d7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_risk_high['risk'] = 1

# %%
df_risk_low = df_not_zero[df_not_zero['customer_cost']>0.02]
df_risk_low['risk'] = 0
# Out:
# <ipython-input-130-1b138c8c8d6c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_risk_low['risk'] = 0

# %%
df_risk_low.columns
# Out:
# Index(['customer_id', 'req_id', 'insu_req_amount', 'insu_pay_amount',
#        'insu_cum_amount', 'insu_duration', 'customer_cost', 'risk'],
#       dtype='object')

# %% [markdown]
# ## 청구금액 0이 아닌 고객 risk column merge

# %%
df_not_zero_risk =pd.merge(df_risk_high,df_risk_low, on =['customer_id', 'req_id', 'insu_req_amount', 'insu_pay_amount',
       'insu_cum_amount', 'insu_duration', 'customer_cost', 'risk'], how = 'outer')

# %%
df_not_zero_risk.isna().sum()
# Out:
# customer_id        0
# req_id             0
# insu_req_amount    0
# insu_pay_amount    0
# insu_cum_amount    0
# insu_duration      0
# customer_cost      0
# risk               0
# dtype: int64

# %%
df_not_zero_risk
# Out:
#      customer_id                         req_id  insu_req_amount  \
# 0        C112379  C112379-20110314-17403-01-001           623098
# 1        C112404  C112404-20100831-12754-01-001           808750
# 2        C112411  C112411-20101111-18755-01-001           333680
# 3        C112570  C112570-20130716-13737-01-001          2762279
# 4        C112856  C112856-20120717-16134-02-001           234820
# ...          ...                            ...              ...
# 2078     C133614  C133614-20121220-18985-01-001           262570
# 2079     C133633  C133633-20130806-12110-01-001           325600
# 2080     C133640  C133640-20121024-13962-01-001            92624
# 2081     C133760  C133760-20120813-15856-01-001          4808179
# 2082     C134184  C134184-20130611-13903-02-001           383160
#
#       insu_pay_amount  insu_cum_amount  insu_duration  customer_cost  risk
# 0           1214577.0          1800000             15      -0.949255     1
# 1           1008750.0           600000              5      -0.247295     1
# 2            553680.0           240000              2      -0.659314     1
# 3           2852279.0          4875000             39      -0.032582     1
# 4            314820.0          2875000             23      -0.340686     1
# ...               ...              ...            ...            ...   ...
# 2078         252570.0          6380000             29       0.038085     0
# 2079         296509.0          8360000             38       0.089346     0
# 2080          33812.0          6380000             29       0.634954     0
# 2081        2529090.0          1080000             27       0.474003     0
# 2082         342010.0          7480000             34       0.107396     0
#
# [2083 rows x 8 columns]

# %%
df_not_zero_risk.groupby('risk').count()
# Out:
#       customer_id  req_id  insu_req_amount  insu_pay_amount  insu_cum_amount  \
# risk
# 0             444     444              444              444              444
# 1            1639    1639             1639             1639             1639
#
#       insu_duration  customer_cost
# risk
# 0               444            444
# 1              1639           1639

# %%
df_risk = df_not_zero_risk
df_risk
# Out:
#      customer_id                         req_id  insu_req_amount  \
# 0        C112379  C112379-20110314-17403-01-001           623098
# 1        C112404  C112404-20100831-12754-01-001           808750
# 2        C112411  C112411-20101111-18755-01-001           333680
# 3        C112570  C112570-20130716-13737-01-001          2762279
# 4        C112856  C112856-20120717-16134-02-001           234820
# ...          ...                            ...              ...
# 2078     C133614  C133614-20121220-18985-01-001           262570
# 2079     C133633  C133633-20130806-12110-01-001           325600
# 2080     C133640  C133640-20121024-13962-01-001            92624
# 2081     C133760  C133760-20120813-15856-01-001          4808179
# 2082     C134184  C134184-20130611-13903-02-001           383160
#
#       insu_pay_amount  insu_cum_amount  insu_duration  customer_cost  risk
# 0           1214577.0          1800000             15      -0.949255     1
# 1           1008750.0           600000              5      -0.247295     1
# 2            553680.0           240000              2      -0.659314     1
# 3           2852279.0          4875000             39      -0.032582     1
# 4            314820.0          2875000             23      -0.340686     1
# ...               ...              ...            ...            ...   ...
# 2078         252570.0          6380000             29       0.038085     0
# 2079         296509.0          8360000             38       0.089346     0
# 2080          33812.0          6380000             29       0.634954     0
# 2081        2529090.0          1080000             27       0.474003     0
# 2082         342010.0          7480000             34       0.107396     0
#
# [2083 rows x 8 columns]

# %%
df_risk0= df_risk[df_risk['risk']== 0]

# %%
df_risk['risk'].value_counts()
# Out:
# 1    1639
# 0     444
# Name: risk, dtype: int64

# %%
df_risk[df_risk['risk'] == 1]
# Out:
#      customer_id                         req_id  insu_req_amount  \
# 0        C112379  C112379-20110314-17403-01-001           623098
# 1        C112404  C112404-20100831-12754-01-001           808750
# 2        C112411  C112411-20101111-18755-01-001           333680
# 3        C112570  C112570-20130716-13737-01-001          2762279
# 4        C112856  C112856-20120717-16134-02-001           234820
# ...          ...                            ...              ...
# 1634     C134172  C134172-20120418-11473-01-001            62770
# 1635     C134188  C134188-20121011-13181-02-001          2923139
# 1636     C134197  C134197-20130403-15406-01-001          1891048
# 1637     C134221  C134221-20130917-12901-02-001          6281720
# 1638     C134250  C134250-20130607-14972-01-001          3367672
#
#       insu_pay_amount  insu_cum_amount  insu_duration  customer_cost  risk
# 0           1214577.0          1800000             15      -0.949255     1
# 1           1008750.0           600000              5      -0.247295     1
# 2            553680.0           240000              2      -0.659314     1
# 3           2852279.0          4875000             39      -0.032582     1
# 4            314820.0          2875000             23      -0.340686     1
# ...               ...              ...            ...            ...   ...
# 1634         262770.0          2700000             27      -3.186235     1
# 1635        6113139.0          1120000             28      -1.091293     1
# 1636        1901048.0          4000000             40      -0.005288     1
# 1637        9951053.0          3600000             36      -0.584129     1
# 1638        3407672.0          1650000             33      -0.011878     1
#
# [1639 rows x 8 columns]

# %%
plt.figure(figsize = (6,7))
boxplot = df_not_zero_risk.boxplot(column = ['customer_cost'])
plt.yticks(np.arange(-5,5, step = 50))
df_not_zero_risk
plt.show()

# %%
df_not_zero_risk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2083 entries, 0 to 2082
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      2083 non-null   object
#  1   req_id           2083 non-null   object
#  2   insu_req_amount  2083 non-null   int64
#  3   insu_pay_amount  2083 non-null   float64
#  4   insu_cum_amount  2083 non-null   int64
#  5   insu_duration    2083 non-null   int64
#  6   customer_cost    2083 non-null   float64
#  7   risk             2083 non-null   int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 146.5+ KB

# %%
df_not_zero_risk.head()
# Out:
#   customer_id                         req_id  insu_req_amount  \
# 0     C112379  C112379-20110314-17403-01-001           623098
# 1     C112404  C112404-20100831-12754-01-001           808750
# 2     C112411  C112411-20101111-18755-01-001           333680
# 3     C112570  C112570-20130716-13737-01-001          2762279
# 4     C112856  C112856-20120717-16134-02-001           234820
#
#    insu_pay_amount  insu_cum_amount  insu_duration  customer_cost  risk
# 0        1214577.0          1800000             15      -0.949255     1
# 1        1008750.0           600000              5      -0.247295     1
# 2         553680.0           240000              2      -0.659314     1
# 3        2852279.0          4875000             39      -0.032582     1
# 4         314820.0          2875000             23      -0.340686     1

# %%
df_risk['risk'].value_counts()
# Out:
# 1    1639
# 0     444
# Name: risk, dtype: int64

# %%
plt.figure(figsize = (6,7))
boxplot = df_not_zero_risk.boxplot(column = ['customer_cost'])
plt.yticks(np.arange(-5,5, step = 50))
df_not_zero_risk
plt.show()

# %%
df_not_zero_risk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2083 entries, 0 to 2082
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      2083 non-null   object
#  1   req_id           2083 non-null   object
#  2   insu_req_amount  2083 non-null   int64
#  3   insu_pay_amount  2083 non-null   float64
#  4   insu_cum_amount  2083 non-null   int64
#  5   insu_duration    2083 non-null   int64
#  6   customer_cost    2083 non-null   float64
#  7   risk             2083 non-null   int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 146.5+ KB

# %% [markdown]
# ## insu_risk csv로 저장

# %%
df_risk.to_csv('./DATA/insu_risk.csv',encoding = 'euckr')
